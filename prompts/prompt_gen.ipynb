# %%
import os
import json

def generate_vlm_prompts(annotation_dir):
    """
    Reads annotation JSON files and generates prompts for a Vision-Language Model (VLM).

    Args:
        annotation_dir (str): Directory containing annotation JSON files.
        
    Returns:
        dict: A dictionary where keys are filenames and values are generated prompts.
    """
    prompts = {}

    for filename in os.listdir(annotation_dir):
        if filename.endswith('.json'):
            file_path = os.path.join(annotation_dir, filename)

            with open(file_path, 'r') as file:
                data = json.load(file)

                # Extract relevant information
                detections = data.get('detections', [])
                image_path = data.get('image_path', 'unknown image path')
                robot_pose = data.get('robot_pose', {})

                # Handle cases where robot_pose is None
                if robot_pose is None:
                    translation = {"x": 0, "y": 0, "z": 0}
                    orientation = {"x": 0, "y": 0, "z": 0, "w": 0}
                else:
                    translation = robot_pose.get('translation', {"x": 0, "y": 0, "z": 0})
                    orientation = robot_pose.get('orientation', {"x": 0, "y": 0, "z": 0, "w": 0})

                # Generate prompt parts for detections
                prompt_parts = []
                for detection in detections:
                    obj_class = detection.get('class', 'unknown object')
                    confidence = detection.get('confidence', 0)
                    bbox = detection.get('bbox', {})
                    center_x = bbox.get('center_x', 0)
                    center_y = bbox.get('center_y', 0)
                    size_x = bbox.get('size_x', 0)
                    size_y = bbox.get('size_y', 0)
                    median_depth = detection.get('median_depth', 'unknown depth')
                    feature_vector = detection.get('feature_vector', [])
                    feature_vector_str = ', '.join(f"{v:.2f}" for v in feature_vector[:5]) + "..." if feature_vector else "no features"
                    prompt_parts.append(
                        f"a {obj_class} with confidence {confidence:.2f} "
                        f"at center ({center_x:.2f}, {center_y:.2f}) "
                        f"and size ({size_x:.2f}, {size_y:.2f}),"
                        f"median depth {median_depth}, "
                        f"features [{feature_vector_str}]"
                    )

                # Combine all parts into a single prompt
                detection_description = ", ".join(prompt_parts) if prompt_parts else "no objects detected"
                robot_pose_description = (
                    f"Robot is at translation ({translation.get('x', 0):.2f}, "
                    f"{translation.get('y', 0):.2f}, {translation.get('z', 0):.2f}) "
                    f"and orientation ({orientation.get('x', 0):.2f}, {orientation.get('y', 0):.2f}, "
                    f"{orientation.get('z', 0):.2f}, {orientation.get('w', 0):.2f})."
                )
                prompt = (
                    f"In the image at {image_path}, {detection_description}. "
                    f"{robot_pose_description}"
                )
                prompts[filename] = prompt

    return prompts


annotation_directory = "/Users/esort/Downloads/annotations_with_features_and_depth"
vlm_prompts = generate_vlm_prompts(annotation_directory)

for file, prompt in vlm_prompts.items():
    print(f"{file}: {prompt}")
# Out:
# 20250416_120444_324.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120444_324.jpg, a person with confidence 0.60 at center (1896.36, 432.28) and size (46.55, 322.13),median depth 7.0, features [0.16, -0.19, -0.03, -0.26, 0.20...]. Robot is at translation (6.78, -0.05, 0.01) and orientation (0.00, 0.00, 0.30, 0.95).
# 20250416_115221_557.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115221_557.jpg, a chair with confidence 0.93 at center (349.60, 487.05) and size (116.68, 156.97),median depth 13.0, features [-0.01, 0.13, 0.24, -0.26, 0.63...], a chair with confidence 0.60 at center (597.80, 494.42) and size (82.91, 149.13),median depth 13.0, features [0.31, -0.13, 0.28, -0.30, 0.55...], a dining table with confidence 0.52 at center (464.47, 495.47) and size (153.09, 151.81),median depth 13.0, features [0.12, 0.12, 0.32, 0.14, 0.01...]. Robot is at translation (2.53, 0.61, 0.01) and orientation (0.00, 0.00, -0.24, 0.97).
# 20250416_120421_872.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120421_872.jpg, a chair with confidence 0.82 at center (930.93, 455.92) and size (124.72, 248.94),median depth 9.0, features [0.10, 0.05, 0.18, 0.02, 0.40...], a chair with confidence 0.73 at center (554.98, 453.03) and size (198.59, 254.84),median depth 9.0, features [0.25, 0.13, 0.24, -0.22, 0.34...], a refrigerator with confidence 0.72 at center (1176.78, 384.02) and size (217.78, 364.54),median depth 9.0, features [0.12, 0.18, -0.05, -0.07, 0.28...], a vase with confidence 0.68 at center (1598.59, 503.99) and size (197.89, 238.61),median depth 2.0, features [-0.10, 0.06, 0.16, 0.37, 0.32...], a dining table with confidence 0.61 at center (730.59, 459.22) and size (229.72, 233.08),median depth 9.0, features [0.17, 0.18, 0.29, 0.18, -0.02...]. Robot is at translation (6.14, -0.23, 0.01) and orientation (0.00, 0.00, -0.07, 1.00).
# 20250416_121022_564.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_121022_564.jpg, a chair with confidence 0.75 at center (1127.04, 376.43) and size (312.01, 480.47),median depth 4.0, features [0.13, 0.04, -0.10, 0.21, 0.34...]. Robot is at translation (9.59, -2.10, 0.01) and orientation (0.00, 0.00, 0.45, 0.89).
# 20250416_115616_917.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115616_917.jpg, a traffic light with confidence 0.51 at center (928.39, 288.05) and size (30.21, 90.69),median depth 9.0, features [0.49, -0.11, -0.32, -0.26, 0.16...]. Robot is at translation (3.22, -1.69, 0.01) and orientation (0.00, 0.00, -0.06, 1.00).
# 20250416_115038_753.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115038_753.jpg, a person with confidence 0.57 at center (377.20, 63.86) and size (72.93, 126.40),median depth 3.0, features [-0.02, 0.27, -0.33, -0.03, -0.26...]. Robot is at translation (-0.40, 2.75, 0.01) and orientation (0.00, 0.00, -0.75, 0.66).
# 20250416_120055_214.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120055_214.jpg, a chair with confidence 0.85 at center (549.86, 483.92) and size (138.45, 174.21),median depth 12.0, features [-0.02, 0.22, 0.16, -0.14, 0.44...], a chair with confidence 0.61 at center (811.96, 493.61) and size (89.39, 147.52),median depth 12.0, features [0.27, 0.20, 0.15, 0.18, 0.62...], a dining table with confidence 0.53 at center (676.34, 493.92) and size (157.20, 156.78),median depth 11.0, features [-0.02, 0.03, 0.31, -0.01, 0.15...]. Robot is at translation (3.33, -0.26, 0.01) and orientation (0.00, 0.00, -0.11, 0.99).
# 20250416_120108_444.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120108_444.jpg, a person with confidence 0.78 at center (657.59, 481.06) and size (126.85, 191.64),median depth 5.0, features [0.23, -0.28, -0.06, 0.52, 0.43...], a tv with confidence 0.51 at center (145.45, 271.01) and size (290.89, 314.21),median depth 6.0, features [-0.37, 0.27, -0.18, 0.21, -0.06...]. Robot is at translation (3.38, -0.33, 0.01) and orientation (0.00, 0.00, -0.54, 0.84).
# 20250416_115011_524.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115011_524.jpg, a person with confidence 0.55 at center (1761.82, 131.93) and size (70.91, 168.44),median depth 4.0, features [0.08, 0.39, 0.01, -0.09, -0.15...]. Robot is at translation (0.02, 3.83, 0.01) and orientation (0.00, 0.00, -0.62, 0.78).
# 20250416_114708_051.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_114708_051.jpg, a refrigerator with confidence 0.53 at center (1558.32, 485.42) and size (271.73, 350.00),median depth 2.0, features [-0.09, 0.23, 0.20, 0.21, 0.29...]. Robot is at translation (-2.05, 0.97, 0.01) and orientation (0.00, 0.00, 0.62, 0.79).
# 20250416_115926_092.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115926_092.jpg, a cup with confidence 0.65 at center (1647.38, 526.98) and size (88.97, 111.86),median depth 6.0, features [-0.09, 0.02, -0.39, -0.02, 0.31...]. Robot is at translation (3.65, 0.23, 0.01) and orientation (0.00, 0.00, 0.94, -0.33).
# 20250416_120526_889.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120526_889.jpg, a chair with confidence 0.90 at center (1594.98, 438.44) and size (222.74, 296.87),median depth 8.0, features [0.12, 0.14, 0.24, -0.08, 0.51...], a dining table with confidence 0.65 at center (1800.41, 439.05) and size (237.84, 313.78),median depth 8.0, features [0.25, 0.00, 0.18, 0.04, 0.18...]. Robot is at translation (6.89, 0.02, 0.01) and orientation (0.00, 0.00, 0.18, 0.98).
# 20250416_120750_315.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120750_315.jpg, a refrigerator with confidence 0.58 at center (85.28, 475.77) and size (168.15, 198.31),median depth 8.0, features [0.03, 0.23, 0.02, -0.41, 0.60...], a tv with confidence 0.56 at center (1438.88, 85.97) and size (261.02, 129.15),median depth 7.0, features [-0.04, -0.04, 0.20, -0.06, 0.51...]. Robot is at translation (8.21, 1.20, 0.01) and orientation (0.00, 0.00, -0.75, 0.66).
# 20250416_120554_700.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120554_700.jpg, a chair with confidence 0.86 at center (644.24, 416.30) and size (190.04, 352.98),median depth 8.0, features [0.13, 0.17, 0.07, 0.13, 0.45...]. Robot is at translation (8.05, -0.09, 0.01) and orientation (0.00, 0.00, -0.21, 0.98).
# 20250416_120751_315.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120751_315.jpg, no objects detected. Robot is at translation (8.21, 1.17, 0.01) and orientation (0.00, 0.00, -0.73, 0.68).
# 20250416_120308_730.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120308_730.jpg, a chair with confidence 0.67 at center (1812.90, 478.27) and size (172.02, 183.88),median depth 11.0, features [0.19, 0.16, 0.16, -0.13, 0.30...], a airplane with confidence 0.57 at center (576.04, 470.94) and size (1100.06, 243.38),median depth 7.0, features [0.31, 0.29, 0.27, 0.15, 0.34...]. Robot is at translation (3.38, -0.48, 0.01) and orientation (0.00, 0.00, 0.25, 0.97).
# 20250416_115409_305.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115409_305.jpg, a chair with confidence 0.82 at center (1315.08, 479.20) and size (102.66, 180.33),median depth 12.0, features [0.21, 0.07, 0.33, -0.22, 0.62...], a chair with confidence 0.74 at center (1041.05, 482.56) and size (140.70, 175.19),median depth 12.0, features [0.08, 0.40, 0.15, -0.10, 0.45...], a chair with confidence 0.56 at center (1313.22, 505.39) and size (98.41, 122.46),median depth 12.0, features [0.25, 0.12, 0.26, 0.22, 0.43...]. Robot is at translation (4.06, -0.53, 0.01) and orientation (0.00, 0.00, -0.07, 1.00).
# 20250416_115917_966.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115917_966.jpg, a person with confidence 0.81 at center (974.01, 481.66) and size (128.63, 188.54),median depth 5.0, features [0.29, -0.26, -0.16, 0.56, 0.44...], a refrigerator with confidence 0.70 at center (165.70, 442.81) and size (326.91, 287.83),median depth 3.0, features [0.14, 0.23, -0.27, 0.31, 0.30...]. Robot is at translation (3.65, 0.23, 0.01) and orientation (0.00, 0.00, -0.37, 0.93).
# 20250416_114710_382.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_114710_382.jpg, a chair with confidence 0.91 at center (1406.86, 305.28) and size (314.61, 606.56),median depth 4.0, features [-0.02, -0.04, 0.15, 0.27, 0.30...], a cup with confidence 0.63 at center (951.21, 492.86) and size (239.08, 327.18),median depth 2.0, features [-0.09, -0.10, 0.04, 0.12, 0.35...]. Robot is at translation (-2.04, 1.01, 0.01) and orientation (0.00, 0.00, 0.56, 0.83).
# 20250416_120419_341.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120419_341.jpg, a chair with confidence 0.72 at center (261.52, 450.68) and size (214.09, 271.68),median depth 9.0, features [0.11, 0.15, 0.26, -0.16, 0.34...], a dining table with confidence 0.51 at center (447.03, 458.21) and size (242.61, 242.61),median depth 9.0, features [-0.07, 0.16, 0.15, -0.11, 0.14...], a chair with confidence 0.51 at center (656.35, 456.99) and size (124.47, 246.92),median depth 9.0, features [0.16, 0.11, 0.24, -0.20, 0.40...]. Robot is at translation (6.06, -0.21, 0.01) and orientation (0.00, 0.00, -0.14, 0.99).
# 20250416_115957_021.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115957_021.jpg, a bed with confidence 0.54 at center (1409.10, 393.59) and size (1019.07, 520.28),median depth 2.0, features [0.04, -0.10, -0.22, 0.21, 0.11...]. Robot is at translation (2.87, 0.06, 0.01) and orientation (0.00, 0.00, 1.00, -0.03).
# 20250416_115735_323.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115735_323.jpg, no objects detected. Robot is at translation (3.42, -1.62, 0.01) and orientation (0.00, 0.00, 0.26, 0.97).
# 20250416_115136_762.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115136_762.jpg, a chair with confidence 0.56 at center (716.55, 501.61) and size (71.98, 128.06),median depth 15.0, features [0.04, -0.29, -0.17, -0.13, 0.46...]. Robot is at translation (0.87, 1.43, 0.01) and orientation (0.00, 0.00, -0.23, 0.97).
# 20250416_120254_480.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120254_480.jpg, a airplane with confidence 0.68 at center (1001.71, 472.88) and size (988.63, 229.51),median depth 7.0, features [0.20, 0.18, 0.04, 0.09, 0.33...]. Robot is at translation (3.22, -0.61, 0.01) and orientation (0.00, 0.00, 0.43, 0.90).
# 20250416_115921_867.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115921_867.jpg, a person with confidence 0.61 at center (1069.19, 200.10) and size (123.47, 186.44),median depth 6.0, features [0.06, 0.20, -0.26, 0.11, 0.08...]. Robot is at translation (3.65, 0.23, 0.01) and orientation (0.00, 0.00, -0.71, 0.70).
# 20250416_120624_769.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120624_769.jpg, a chair with confidence 0.86 at center (742.09, 413.47) and size (190.14, 358.88),median depth 7.0, features [0.34, 0.17, 0.04, 0.04, 0.50...], a refrigerator with confidence 0.84 at center (1003.35, 325.85) and size (281.12, 474.53),median depth 7.0, features [0.23, -0.20, -0.11, -0.01, 0.23...]. Robot is at translation (8.16, -0.15, 0.01) and orientation (0.00, 0.00, -0.13, 0.99).
# 20250416_120301_781.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120301_781.jpg, a bench with confidence 0.79 at center (290.86, 472.92) and size (502.92, 230.63),median depth 6.0, features [0.42, 0.32, 0.22, 0.19, 0.09...], a chair with confidence 0.72 at center (1765.64, 478.49) and size (167.03, 182.13),median depth 11.0, features [0.03, 0.16, 0.11, -0.41, 0.30...]. Robot is at translation (3.30, -0.53, 0.01) and orientation (0.00, 0.00, 0.31, 0.95).
# 20250416_120551_295.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120551_295.jpg, a chair with confidence 0.80 at center (758.98, 469.73) and size (176.44, 239.13),median depth 6.0, features [0.24, 0.33, 0.12, 0.24, 0.31...], a chair with confidence 0.73 at center (169.27, 398.27) and size (234.38, 391.55),median depth 7.0, features [0.13, 0.08, 0.12, -0.08, 0.46...], a chair with confidence 0.67 at center (761.82, 418.60) and size (180.85, 344.53),median depth 8.0, features [0.19, 0.18, 0.10, 0.10, 0.33...]. Robot is at translation (7.97, -0.06, 0.01) and orientation (0.00, 0.00, -0.18, 0.98).
# 20250416_115103_555.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115103_555.jpg, no objects detected. Robot is at translation (-0.24, 2.61, 0.01) and orientation (0.00, 0.00, -0.41, 0.91).
# 20250416_120352_338.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120352_338.jpg, a chair with confidence 0.81 at center (1373.15, 466.14) and size (112.98, 219.19),median depth 10.0, features [0.18, -0.09, 0.05, -0.08, 0.43...], a chair with confidence 0.81 at center (1047.02, 471.81) and size (152.91, 211.59),median depth 11.0, features [0.01, 0.21, -0.03, -0.22, 0.31...], a dining table with confidence 0.56 at center (1199.36, 475.18) and size (191.84, 201.42),median depth 10.0, features [0.13, 0.02, 0.42, 0.14, -0.11...]. Robot is at translation (5.06, 0.05, 0.01) and orientation (0.00, 0.00, -0.01, 1.00).
# 20250416_120747_007.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120747_007.jpg, a tv with confidence 0.65 at center (438.49, 82.75) and size (260.14, 142.29),median depth 7.0, features [-0.18, 0.15, 0.34, 0.05, 0.55...]. Robot is at translation (8.22, 1.21, 0.01) and orientation (0.00, 0.00, -0.86, 0.51).
# 20250416_115958_023.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115958_023.jpg, no objects detected. Robot is at translation (2.87, 0.06, 0.01) and orientation (0.00, 0.00, 1.00, -0.07).
# 20250416_120429_791.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120429_791.jpg, a chair with confidence 0.88 at center (1670.33, 440.28) and size (157.93, 287.18),median depth 8.0, features [-0.00, 0.08, 0.03, 0.14, 0.30...], a chair with confidence 0.78 at center (1245.68, 451.68) and size (193.84, 262.55),median depth 9.0, features [0.20, 0.07, 0.09, -0.36, 0.28...], a refrigerator with confidence 0.52 at center (1872.54, 349.09) and size (93.06, 450.85),median depth 7.0, features [-0.05, -0.09, -0.17, -0.11, 0.03...]. Robot is at translation (6.44, -0.21, 0.01) and orientation (0.00, 0.00, 0.13, 0.99).
# 20250416_120118_593.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120118_593.jpg, a person with confidence 0.78 at center (1173.09, 482.66) and size (125.79, 187.13),median depth 5.0, features [0.17, 0.16, -0.30, 0.17, 0.39...]. Robot is at translation (3.37, -0.30, 0.01) and orientation (0.00, 0.00, -0.29, 0.96).
# 20250416_120931_044.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120931_044.jpg, no objects detected. Robot is at translation (9.37, -1.38, 0.01) and orientation (0.00, 0.00, -0.55, 0.83).
# 20250416_115411_096.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115411_096.jpg, a chair with confidence 0.85 at center (1295.21, 477.62) and size (100.75, 180.22),median depth 12.0, features [0.15, 0.12, 0.25, -0.21, 0.59...], a chair with confidence 0.69 at center (1020.48, 481.63) and size (139.24, 175.93),median depth 12.0, features [0.10, 0.37, 0.13, -0.12, 0.38...], a sports ball with confidence 0.58 at center (239.53, 502.95) and size (202.86, 160.76),median depth 7.0, features [0.51, -0.12, -0.48, 0.24, 0.33...]. Robot is at translation (4.07, -0.53, 0.01) and orientation (0.00, 0.00, -0.09, 1.00).
# 20250416_120659_877.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120659_877.jpg, no objects detected. Robot is at translation (8.33, 0.73, 0.01) and orientation (0.00, 0.00, 0.72, 0.69).
# 20250416_120313_691.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120313_691.jpg, no objects detected. Robot is at translation (3.61, -0.37, 0.01) and orientation (0.00, 0.00, 0.19, 0.98).
# 20250416_115134_496.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115134_496.jpg, a refrigerator with confidence 0.52 at center (823.19, 451.79) and size (197.90, 226.61),median depth 15.0, features [0.22, 0.35, -0.12, -0.17, 0.40...]. Robot is at translation (0.77, 1.48, 0.01) and orientation (0.00, 0.00, -0.25, 0.97).
# 20250416_115023_148.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115023_148.jpg, no objects detected. Robot is at translation (-0.08, 3.32, 0.01) and orientation (0.00, 0.00, -0.86, 0.51).
# 20250416_115424_720.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115424_720.jpg, a cup with confidence 0.59 at center (249.20, 521.43) and size (111.22, 140.66),median depth 4.0, features [-0.02, -0.06, 0.11, 0.11, 0.44...]. Robot is at translation (4.24, -0.68, 0.01) and orientation (0.00, 0.00, -0.43, 0.90).
# 20250416_115427_800.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115427_800.jpg, a person with confidence 0.57 at center (1879.78, 251.40) and size (49.75, 122.26),median depth 5.0, features [0.08, 0.33, -0.05, 0.01, -0.29...]. Robot is at translation (4.29, -0.75, 0.01) and orientation (0.00, 0.00, -0.48, 0.88).
# 20250416_120540_549.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120540_549.jpg, a chair with confidence 0.89 at center (650.59, 423.58) and size (230.48, 329.29),median depth 8.0, features [0.16, 0.16, 0.18, -0.10, 0.59...], a chair with confidence 0.85 at center (1130.80, 429.37) and size (174.31, 319.23),median depth 8.0, features [0.09, 0.27, 0.13, -0.21, 0.61...], a dining table with confidence 0.69 at center (874.82, 440.06) and size (272.42, 305.48),median depth 8.0, features [0.33, -0.08, 0.23, 0.10, 0.12...]. Robot is at translation (7.59, 0.04, 0.01) and orientation (0.00, 0.00, -0.08, 1.00).
# 20250416_120141_023.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120141_023.jpg, a sports ball with confidence 0.70 at center (1842.05, 500.59) and size (154.28, 155.29),median depth 8.0, features [0.30, 0.04, 0.01, 0.11, 0.27...], a airplane with confidence 0.52 at center (1561.69, 297.91) and size (716.63, 582.95),median depth 8.0, features [0.61, 0.40, -0.11, 0.40, 0.17...]. Robot is at translation (3.37, -0.28, 0.01) and orientation (0.00, 0.00, 0.61, 0.79).
# 20250416_115908_979.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115908_979.jpg, no objects detected. Robot is at translation (3.63, 0.24, 0.01) and orientation (0.00, 0.00, -0.10, 1.00).
# 20250416_120602_248.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120602_248.jpg, a chair with confidence 0.89 at center (459.99, 409.25) and size (201.26, 375.09),median depth 7.0, features [0.18, 0.25, 0.21, 0.11, 0.51...], a refrigerator with confidence 0.57 at center (733.84, 324.92) and size (280.60, 489.44),median depth 7.0, features [0.05, -0.01, -0.26, -0.11, 0.31...]. Robot is at translation (8.16, -0.15, 0.01) and orientation (0.00, 0.00, -0.25, 0.97).
# 20250416_115222_617.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115222_617.jpg, a chair with confidence 0.76 at center (342.37, 489.89) and size (114.16, 153.45),median depth 13.0, features [-0.01, 0.26, 0.12, -0.21, 0.63...], a chair with confidence 0.65 at center (590.27, 491.67) and size (82.43, 151.52),median depth 13.0, features [0.19, 0.02, 0.10, -0.12, 0.47...]. Robot is at translation (2.54, 0.60, 0.01) and orientation (0.00, 0.00, -0.24, 0.97).
# 20250416_120641_182.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120641_182.jpg, no objects detected. Robot is at translation (8.25, -0.03, 0.01) and orientation (0.00, 0.00, 0.53, 0.85).
# 20250416_120403_852.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120403_852.jpg, a chair with confidence 0.83 at center (551.14, 461.58) and size (170.46, 241.36),median depth 10.0, features [0.19, 0.07, 0.11, -0.32, 0.33...], a chair with confidence 0.80 at center (904.13, 462.64) and size (114.95, 228.69),median depth 10.0, features [0.21, 0.04, -0.04, 0.01, 0.45...], a dining table with confidence 0.56 at center (719.05, 470.21) and size (203.57, 210.55),median depth 10.0, features [0.09, 0.12, 0.03, 0.02, 0.19...]. Robot is at translation (5.65, -0.04, 0.01) and orientation (0.00, 0.00, -0.14, 0.99).
# 20250416_115457_597.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115457_597.jpg, a person with confidence 0.83 at center (1000.44, 470.86) and size (156.66, 223.53),median depth 4.0, features [0.10, -0.24, -0.01, 0.60, 0.38...]. Robot is at translation (4.39, -1.28, 0.01) and orientation (0.00, 0.00, -0.79, 0.61).
# 20250416_120126_068.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120126_068.jpg, a chair with confidence 0.62 at center (69.09, 479.05) and size (114.63, 185.93),median depth 11.0, features [0.01, 0.10, 0.38, -0.07, 0.60...]. Robot is at translation (3.37, -0.30, 0.01) and orientation (0.00, 0.00, -0.04, 1.00).
# 20250416_121055_103.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_121055_103.jpg, no objects detected. Robot is at translation (10.07, -1.47, 0.01) and orientation (0.00, 0.00, -0.34, 0.94).
# 20250416_120622_738.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120622_738.jpg, a refrigerator with confidence 0.69 at center (821.42, 323.61) and size (282.78, 479.00),median depth 7.0, features [0.28, 0.15, -0.07, 0.07, 0.33...], a chair with confidence 0.68 at center (550.08, 463.88) and size (187.71, 256.72),median depth 5.0, features [0.19, 0.27, 0.25, 0.25, 0.28...], a chair with confidence 0.68 at center (552.62, 408.69) and size (193.92, 370.33),median depth 7.0, features [0.05, 0.18, 0.06, 0.09, 0.34...], a chair with confidence 0.66 at center (47.92, 474.73) and size (95.70, 232.74),median depth 7.0, features [0.15, 0.58, 0.18, 0.14, 0.43...]. Robot is at translation (8.16, -0.15, 0.01) and orientation (0.00, 0.00, -0.22, 0.97).
# 20250416_120553_570.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120553_570.jpg, a chair with confidence 0.76 at center (674.51, 467.67) and size (179.56, 242.80),median depth 7.0, features [0.14, 0.25, 0.22, 0.29, 0.29...], a refrigerator with confidence 0.68 at center (928.48, 331.25) and size (273.57, 469.30),median depth 7.0, features [0.32, 0.24, -0.03, 0.20, 0.33...]. Robot is at translation (8.02, -0.08, 0.01) and orientation (0.00, 0.00, -0.20, 0.98).
# 20250416_115400_321.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115400_321.jpg, a chair with confidence 0.80 at center (790.27, 485.17) and size (135.92, 169.58),median depth 13.0, features [0.02, 0.30, 0.16, -0.15, 0.39...]. Robot is at translation (3.58, -0.45, 0.01) and orientation (0.00, 0.00, -0.13, 0.99).
# 20250416_120642_627.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120642_627.jpg, a person with confidence 0.71 at center (149.37, 406.02) and size (298.73, 415.52),median depth 5.0, features [0.02, 0.41, 0.09, 0.02, 0.29...]. Robot is at translation (8.27, 0.00, 0.01) and orientation (0.00, 0.00, 0.56, 0.83).
# 20250416_121058_574.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_121058_574.jpg, a person with confidence 0.81 at center (1873.60, 498.53) and size (91.29, 146.88),median depth 5.0, features [-0.51, -0.05, -0.22, -0.03, 0.00...]. Robot is at translation (10.07, -1.47, 0.01) and orientation (0.00, 0.00, -0.34, 0.94).
# 20250416_114711_911.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_114711_911.jpg, a chair with confidence 0.81 at center (1063.07, 303.97) and size (301.37, 607.94),median depth 4.0, features [-0.06, 0.09, 0.15, -0.13, 0.41...], a chair with confidence 0.57 at center (1058.10, 390.67) and size (289.99, 439.06),median depth 4.0, features [-0.01, 0.12, -0.12, -0.10, 0.29...], a refrigerator with confidence 0.52 at center (601.21, 487.85) and size (256.01, 343.47),median depth 2.0, features [-0.06, 0.06, 0.20, 0.35, 0.12...]. Robot is at translation (-2.01, 1.07, 0.01) and orientation (0.00, 0.00, 0.51, 0.86).
# 20250416_120059_269.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120059_269.jpg, a person with confidence 0.79 at center (1850.34, 473.95) and size (137.41, 215.60),median depth 5.0, features [0.38, 0.16, 0.12, -0.00, 0.69...]. Robot is at translation (3.34, -0.26, 0.01) and orientation (0.00, 0.00, -0.43, 0.90).
# 20250416_120640_032.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120640_032.jpg, a orange with confidence 0.57 at center (55.65, 311.49) and size (110.87, 248.32),median depth 3.0, features [-0.00, 0.13, -0.14, -0.03, 0.55...]. Robot is at translation (8.25, -0.04, 0.01) and orientation (0.00, 0.00, 0.51, 0.86).
# 20250416_120743_585.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120743_585.jpg, a traffic light with confidence 0.52 at center (631.60, 334.87) and size (64.05, 128.06),median depth 11.0, features [0.02, -0.28, -0.11, -0.26, -0.01...]. Robot is at translation (8.22, 1.21, 0.01) and orientation (0.00, 0.00, 0.97, -0.23).
# 20250416_115555_942.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115555_942.jpg, a person with confidence 0.66 at center (224.36, 236.11) and size (125.70, 164.38),median depth 6.0, features [-0.07, 0.30, -0.31, 0.45, 0.31...]. Robot is at translation (3.32, -1.76, 0.01) and orientation (0.00, 0.00, 0.97, 0.25).
# 20250416_120532_789.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120532_789.jpg, a chair with confidence 0.85 at center (1004.62, 437.30) and size (201.19, 296.54),median depth 9.0, features [0.22, 0.02, 0.18, -0.33, 0.35...], a chair with confidence 0.76 at center (1459.58, 434.17) and size (167.13, 306.27),median depth 8.0, features [0.15, 0.20, 0.01, 0.04, 0.51...]. Robot is at translation (7.18, 0.07, 0.01) and orientation (0.00, 0.00, 0.02, 1.00).
# 20250416_120549_002.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120549_002.jpg, a chair with confidence 0.75 at center (834.56, 422.62) and size (184.67, 337.47),median depth 8.0, features [0.05, 0.30, 0.14, -0.08, 0.52...], a dining table with confidence 0.74 at center (549.88, 426.15) and size (304.89, 347.11),median depth 8.0, features [0.27, -0.21, 0.02, 0.05, 0.34...], a chair with confidence 0.74 at center (277.35, 403.87) and size (254.18, 376.36),median depth 7.0, features [0.07, -0.05, 0.29, -0.11, 0.45...]. Robot is at translation (7.91, -0.03, 0.01) and orientation (0.00, 0.00, -0.16, 0.99).
# 20250416_115149_506.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115149_506.jpg, a chair with confidence 0.62 at center (591.65, 496.61) and size (73.98, 135.61),median depth 15.0, features [0.11, -0.11, 0.27, 0.04, 0.27...], a tv with confidence 0.53 at center (1877.11, 124.70) and size (84.38, 135.24),median depth 8.0, features [-0.26, 0.01, -0.11, -0.26, 0.46...]. Robot is at translation (1.45, 1.13, 0.01) and orientation (0.00, 0.00, -0.26, 0.96).
# 20250416_120328_001.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120328_001.jpg, a chair with confidence 0.78 at center (1433.47, 478.31) and size (155.99, 186.31),median depth 11.0, features [0.20, 0.15, 0.20, -0.21, 0.50...], a chair with confidence 0.75 at center (1754.40, 469.15) and size (115.13, 206.47),median depth 10.0, features [0.11, 0.13, 0.26, -0.17, 0.64...], a sports ball with confidence 0.52 at center (642.68, 503.78) and size (185.29, 159.57),median depth 7.0, features [0.42, 0.00, -0.35, 0.18, 0.21...], a dining table with confidence 0.52 at center (1580.50, 479.53) and size (197.64, 181.25),median depth 11.0, features [0.15, 0.12, 0.37, 0.04, 0.01...]. Robot is at translation (4.06, -0.22, 0.01) and orientation (0.00, 0.00, 0.15, 0.99).
# 20250416_121046_570.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_121046_570.jpg, a chair with confidence 0.87 at center (1764.40, 336.50) and size (309.83, 611.02),median depth 3.0, features [0.08, 0.11, 0.18, 0.29, 0.29...], a chair with confidence 0.63 at center (716.38, 387.61) and size (453.17, 501.78),median depth 3.0, features [0.33, 0.26, 0.15, 0.35, 0.29...], a chair with confidence 0.56 at center (1023.60, 324.07) and size (263.52, 627.02),median depth 2.0, features [0.06, 0.10, -0.03, 0.15, 0.40...]. Robot is at translation (10.07, -1.47, 0.01) and orientation (0.00, 0.00, 0.30, 0.95).
# 20250416_120902_413.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120902_413.jpg, a chair with confidence 0.71 at center (188.64, 356.73) and size (294.02, 517.87),median depth 6.0, features [0.17, -0.09, 0.14, 0.27, 0.46...], a refrigerator with confidence 0.67 at center (543.92, 284.88) and size (350.84, 565.25),median depth 6.0, features [0.13, -0.01, -0.18, -0.11, 0.32...]. Robot is at translation (8.88, -0.79, 0.01) and orientation (0.00, 0.00, -0.45, 0.89).
# 20250416_115420_962.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115420_962.jpg, a chair with confidence 0.86 at center (246.85, 476.26) and size (115.20, 188.21),median depth 11.0, features [0.00, 0.13, 0.38, -0.17, 0.60...], a cup with confidence 0.58 at center (515.10, 523.52) and size (104.70, 130.35),median depth 5.0, features [-0.06, 0.19, -0.05, 0.14, 0.42...]. Robot is at translation (4.18, -0.61, 0.01) and orientation (0.00, 0.00, -0.36, 0.93).
# 20250416_120950_045.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120950_045.jpg, a refrigerator with confidence 0.74 at center (1738.82, 411.51) and size (360.04, 736.74),median depth 1.0, features [0.15, 0.10, -0.08, 0.19, 0.22...]. Robot is at translation (9.32, -1.99, 0.01) and orientation (0.00, 0.00, -0.77, 0.63).
# 20250416_114641_393.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_114641_393.jpg, a cup with confidence 0.63 at center (1714.00, 482.11) and size (272.91, 341.33),median depth 2.0, features [0.16, 0.22, -0.02, 0.04, 0.31...]. Robot is at translation (-1.18, 0.75, 0.01) and orientation (0.00, 0.00, 0.93, 0.37).
# 20250416_115815_121.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115815_121.jpg, no objects detected. Robot is at translation (3.84, -1.06, 0.01) and orientation (0.00, 0.00, 0.96, 0.28).
# 20250416_120356_268.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120356_268.jpg, a chair with confidence 0.77 at center (1168.56, 467.08) and size (112.68, 216.57),median depth 10.0, features [0.04, 0.07, 0.10, 0.12, 0.34...], a chair with confidence 0.69 at center (840.71, 466.54) and size (153.24, 218.72),median depth 11.0, features [0.22, 0.19, 0.17, -0.23, 0.47...]. Robot is at translation (5.29, 0.04, 0.01) and orientation (0.00, 0.00, -0.06, 1.00).
# 20250416_120418_177.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120418_177.jpg, a chair with confidence 0.80 at center (565.82, 456.38) and size (125.60, 251.69),median depth 9.0, features [0.18, 0.03, 0.21, 0.04, 0.38...], a chair with confidence 0.76 at center (158.45, 445.91) and size (218.81, 277.34),median depth 9.0, features [0.32, 0.20, 0.24, -0.12, 0.34...], a chair with confidence 0.54 at center (114.32, 445.77) and size (132.38, 274.26),median depth 9.0, features [0.10, 0.18, -0.02, -0.10, 0.47...]. Robot is at translation (6.02, -0.20, 0.01) and orientation (0.00, 0.00, -0.17, 0.98).
# 20250416_120338_973.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120338_973.jpg, a chair with confidence 0.84 at center (1544.17, 471.75) and size (166.06, 202.44),median depth 11.0, features [0.24, 0.09, 0.21, -0.35, 0.39...], a chair with confidence 0.67 at center (1876.47, 496.70) and size (84.92, 156.10),median depth 10.0, features [0.12, 0.47, 0.21, 0.06, 0.57...], a dining table with confidence 0.60 at center (1701.59, 475.41) and size (219.26, 197.78),median depth 10.0, features [0.30, 0.06, 0.26, 0.19, -0.02...], a truck with confidence 0.54 at center (856.30, 297.91) and size (1712.59, 595.83),median depth 7.0, features [0.26, 0.26, -0.07, 0.30, 0.25...], a sports ball with confidence 0.52 at center (690.26, 500.28) and size (198.00, 171.84),median depth 6.0, features [0.49, -0.03, -0.30, 0.20, 0.36...]. Robot is at translation (4.55, -0.06, 0.01) and orientation (0.00, 0.00, 0.17, 0.98).
# 20250416_120342_651.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120342_651.jpg, a chair with confidence 0.89 at center (1593.49, 468.76) and size (166.31, 210.78),median depth 10.0, features [0.18, 0.09, 0.23, -0.19, 0.36...]. Robot is at translation (4.65, -0.02, 0.01) and orientation (0.00, 0.00, 0.19, 0.98).
# 20250416_121037_776.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_121037_776.jpg, a person with confidence 0.81 at center (290.84, 280.38) and size (196.16, 315.46),median depth 3.0, features [0.38, 0.28, -0.46, 0.39, 0.31...]. Robot is at translation (9.96, -1.56, 0.01) and orientation (0.00, 0.00, 0.38, 0.93).
# 20250416_120130_116.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120130_116.jpg, a chair with confidence 0.84 at center (208.86, 479.21) and size (109.06, 179.93),median depth 11.0, features [0.12, 0.08, 0.13, -0.24, 0.71...], a refrigerator with confidence 0.51 at center (1677.11, 449.86) and size (403.16, 274.35),median depth 3.0, features [0.13, 0.20, 0.19, 0.22, 0.47...]. Robot is at translation (3.37, -0.30, 0.01) and orientation (0.00, 0.00, -0.03, 1.00).
# 20250416_114635_532.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_114635_532.jpg, a chair with confidence 0.80 at center (1143.37, 309.99) and size (384.43, 617.33),median depth 4.0, features [-0.08, 0.00, 0.05, 0.13, 0.31...]. Robot is at translation (-1.18, 0.74, 0.01) and orientation (0.00, 0.00, 0.74, 0.67).
# 20250416_115036_286.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115036_286.jpg, no objects detected. Robot is at translation (-0.38, 2.85, 0.01) and orientation (0.00, 0.00, -0.80, 0.60).
# 20250416_115423_639.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115423_639.jpg, no objects detected. Robot is at translation (4.23, -0.66, 0.01) and orientation (0.00, 0.00, -0.41, 0.91).
# 20250416_114714_600.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_114714_600.jpg, a chair with confidence 0.60 at center (734.93, 307.00) and size (314.69, 612.99),median depth 4.0, features [0.18, -0.12, -0.09, -0.00, 0.28...], a refrigerator with confidence 0.58 at center (206.25, 477.29) and size (310.42, 384.70),median depth 2.0, features [0.04, 0.03, 0.01, 0.21, 0.25...], a bed with confidence 0.50 at center (1625.57, 377.78) and size (588.86, 572.84),median depth 3.0, features [-0.18, 0.22, -0.04, 0.30, 0.37...]. Robot is at translation (-1.95, 1.16, 0.01) and orientation (0.00, 0.00, 0.45, 0.89).
# 20250416_115557_038.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115557_038.jpg, a person with confidence 0.77 at center (149.55, 228.17) and size (130.23, 163.21),median depth 6.0, features [-0.10, 0.10, -0.29, 0.34, 0.25...], a chair with confidence 0.52 at center (1824.50, 476.60) and size (184.76, 204.48),median depth 7.0, features [0.18, -0.05, 0.03, 0.01, 0.31...]. Robot is at translation (3.30, -1.75, 0.01) and orientation (0.00, 0.00, 0.97, 0.26).
# 20250416_120744_618.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120744_618.jpg, no objects detected. Robot is at translation (8.22, 1.21, 0.01) and orientation (0.00, 0.00, 0.95, -0.32).
# 20250416_120632_670.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120632_670.jpg, a airplane with confidence 0.61 at center (905.11, 369.04) and size (1177.33, 597.75),median depth 5.0, features [0.28, 0.26, 0.12, 0.58, 0.25...]. Robot is at translation (8.18, -0.13, 0.01) and orientation (0.00, 0.00, 0.40, 0.92).
# 20250416_114709_221.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_114709_221.jpg, a chair with confidence 0.92 at center (1656.75, 306.15) and size (340.91, 610.80),median depth 4.0, features [-0.02, 0.26, 0.15, 0.12, 0.55...]. Robot is at translation (-2.05, 0.99, 0.01) and orientation (0.00, 0.00, 0.58, 0.81).
# 20250416_115244_071.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115244_071.jpg, a refrigerator with confidence 0.58 at center (763.01, 474.45) and size (325.52, 218.51),median depth 4.0, features [0.17, 0.27, 0.10, 0.25, 0.37...]. Robot is at translation (3.04, 0.02, 0.01) and orientation (0.00, 0.00, -0.52, 0.85).
# 20250416_120029_547.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120029_547.jpg, a chair with confidence 0.77 at center (109.22, 481.97) and size (112.83, 175.16),median depth 11.0, features [0.07, 0.18, 0.41, -0.18, 0.62...], a chair with confidence 0.64 at center (107.93, 505.39) and size (110.33, 122.67),median depth 11.0, features [0.17, 0.13, 0.30, 0.25, 0.40...]. Robot is at translation (2.87, -0.39, 0.01) and orientation (0.00, 0.00, -0.06, 1.00).
# 20250416_115859_364.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115859_364.jpg, a sports ball with confidence 0.86 at center (1842.43, 499.52) and size (153.42, 159.39),median depth 8.0, features [-0.01, -0.16, -0.21, -0.11, 0.14...], a bench with confidence 0.57 at center (1105.62, 464.80) and size (471.30, 246.43),median depth 6.0, features [0.36, 0.31, 0.09, -0.27, 0.12...]. Robot is at translation (3.57, 0.25, 0.01) and orientation (0.00, 0.00, 0.41, 0.91).
# 20250416_120046_460.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120046_460.jpg, a bench with confidence 0.57 at center (1814.66, 486.31) and size (157.18, 167.47),median depth 11.0, features [0.16, 0.16, 0.14, -0.20, 0.16...], a traffic light with confidence 0.53 at center (1564.00, 274.97) and size (64.00, 101.21),median depth 10.0, features [0.31, -0.02, -0.16, -0.11, 0.76...]. Robot is at translation (3.33, -0.26, 0.01) and orientation (0.00, 0.00, 0.28, 0.96).
# 20250416_114718_944.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_114718_944.jpg, a chair with confidence 0.84 at center (189.48, 308.76) and size (376.55, 615.77),median depth 3.0, features [0.06, -0.05, -0.10, 0.14, 0.50...]. Robot is at translation (-1.75, 1.36, 0.01) and orientation (0.00, 0.00, 0.32, 0.95).
# 20250416_115045_112.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115045_112.jpg, a refrigerator with confidence 0.64 at center (78.98, 536.86) and size (156.53, 601.78),median depth 1.0, features [0.60, -0.33, 0.11, 0.04, 0.39...], a person with confidence 0.51 at center (1575.82, 85.62) and size (56.99, 165.57),median depth 3.0, features [0.10, 0.12, -0.46, -0.14, -0.24...]. Robot is at translation (-0.40, 2.75, 0.01) and orientation (0.00, 0.00, -0.35, 0.94).
# 20250416_114821_928.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_114821_928.jpg, a umbrella with confidence 0.56 at center (680.43, 358.70) and size (999.64, 715.56),median depth 2.0, features [-0.21, 0.21, 0.13, -0.02, 0.34...]. Robot is at translation (-0.74, 2.47, 0.01) and orientation (0.00, 0.00, 0.65, 0.76).
# 20250416_115842_708.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115842_708.jpg, a airplane with confidence 0.53 at center (1451.22, 464.07) and size (619.13, 252.82),median depth 7.0, features [0.30, 0.24, -0.10, -0.24, 0.29...]. Robot is at translation (3.57, -0.12, 0.01) and orientation (0.00, 0.00, 0.67, 0.74).
# 20250416_115734_309.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115734_309.jpg, a airplane with confidence 0.52 at center (238.46, 486.39) and size (476.00, 205.89),median depth 9.0, features [0.35, 0.32, 0.44, 0.37, 0.15...], a traffic light with confidence 0.51 at center (714.20, 282.76) and size (30.72, 92.49),median depth 8.0, features [-0.04, -0.22, -0.13, -0.46, 0.17...]. Robot is at translation (3.38, -1.64, 0.01) and orientation (0.00, 0.00, 0.23, 0.97).
# 20250416_120934_309.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120934_309.jpg, a person with confidence 0.80 at center (1827.64, 500.64) and size (118.93, 143.50),median depth 5.0, features [-0.32, 0.08, -0.06, -0.36, 0.46...]. Robot is at translation (9.37, -1.38, 0.01) and orientation (0.00, 0.00, -0.77, 0.64).
# 20250416_120547_820.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120547_820.jpg, a dining table with confidence 0.72 at center (595.89, 428.96) and size (303.51, 331.49),median depth 8.0, features [0.21, -0.19, 0.21, 0.37, 0.11...], a chair with confidence 0.67 at center (344.47, 411.61) and size (269.45, 365.81),median depth 7.0, features [0.28, 0.13, 0.14, -0.03, 0.35...], a chair with confidence 0.66 at center (874.26, 472.88) and size (176.10, 230.94),median depth 6.0, features [0.15, 0.21, 0.18, 0.26, 0.33...], a chair with confidence 0.53 at center (876.79, 422.67) and size (180.19, 336.85),median depth 8.0, features [0.11, 0.24, 0.06, -0.02, 0.39...], a chair with confidence 0.53 at center (295.59, 408.41) and size (172.93, 368.52),median depth 7.0, features [0.21, 0.02, 0.13, 0.07, 0.31...]. Robot is at translation (7.87, -0.02, 0.01) and orientation (0.00, 0.00, -0.15, 0.99).
# 20250416_115150_555.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115150_555.jpg, a chair with confidence 0.51 at center (562.97, 497.95) and size (75.06, 133.30),median depth 14.0, features [0.27, -0.01, 0.20, -0.23, 0.61...]. Robot is at translation (1.49, 1.11, 0.01) and orientation (0.00, 0.00, -0.27, 0.96).
# 20250416_120034_268.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120034_268.jpg, a chair with confidence 0.76 at center (837.38, 489.30) and size (127.76, 163.72),median depth 13.0, features [0.09, 0.16, 0.30, 0.09, 0.46...], a chair with confidence 0.65 at center (1084.15, 499.37) and size (89.30, 139.84),median depth 13.0, features [0.21, 0.10, 0.35, -0.12, 0.60...], a sports ball with confidence 0.58 at center (127.01, 506.84) and size (211.44, 148.09),median depth 8.0, features [0.41, 0.38, -0.41, 0.41, -0.25...]. Robot is at translation (2.98, -0.38, 0.01) and orientation (0.00, 0.00, 0.05, 1.00).
# 20250416_120117_407.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120117_407.jpg, a person with confidence 0.83 at center (955.58, 483.56) and size (122.22, 186.75),median depth 5.0, features [0.27, -0.25, -0.09, 0.43, 0.37...], a refrigerator with confidence 0.63 at center (133.75, 448.57) and size (266.92, 269.72),median depth 3.0, features [0.27, 0.14, -0.01, 0.17, 0.59...]. Robot is at translation (3.37, -0.30, 0.01) and orientation (0.00, 0.00, -0.35, 0.94).
# 20250416_121017_309.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_121017_309.jpg, a chair with confidence 0.82 at center (1370.24, 378.64) and size (387.07, 471.86),median depth 6.0, features [0.24, -0.01, 0.04, 0.11, 0.23...], a person with confidence 0.62 at center (56.95, 323.77) and size (113.60, 268.37),median depth 4.0, features [-0.05, 0.19, -0.21, 0.23, 0.23...]. Robot is at translation (9.40, -2.30, 0.01) and orientation (0.00, 0.00, 0.32, 0.95).
# 20250416_120759_117.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120759_117.jpg, a chair with confidence 0.64 at center (247.46, 416.78) and size (162.10, 342.38),median depth 7.0, features [0.31, 0.01, 0.26, 0.48, 0.17...], a chair with confidence 0.55 at center (244.64, 467.02) and size (158.63, 240.29),median depth 5.0, features [0.33, 0.08, 0.06, 0.35, 0.08...]. Robot is at translation (8.27, 0.84, 0.01) and orientation (0.00, 0.00, -0.56, 0.83).
# 20250416_115514_311.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115514_311.jpg, a person with confidence 0.59 at center (1490.16, 148.30) and size (126.06, 220.34),median depth 5.0, features [0.51, -0.02, -0.34, 0.05, 0.65...]. Robot is at translation (4.16, -1.61, 0.01) and orientation (0.00, 0.00, 0.94, -0.34).
# 20250416_114716_570.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_114716_570.jpg, a chair with confidence 0.74 at center (490.09, 310.06) and size (353.40, 612.73),median depth 4.0, features [0.18, -0.02, -0.11, 0.36, 0.16...], a bed with confidence 0.59 at center (1519.07, 377.59) and size (799.48, 574.30),median depth 2.0, features [-0.09, 0.26, -0.15, 0.31, 0.25...]. Robot is at translation (-1.88, 1.25, 0.01) and orientation (0.00, 0.00, 0.39, 0.92).
# 20250416_115744_683.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115744_683.jpg, no objects detected. Robot is at translation (3.79, -1.29, 0.01) and orientation (0.00, 0.00, 0.44, 0.90).
# 20250416_115046_140.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115046_140.jpg, no objects detected. Robot is at translation (-0.40, 2.75, 0.01) and orientation (0.00, 0.00, -0.28, 0.96).
# 20250416_115402_773.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115402_773.jpg, a chair with confidence 0.76 at center (1198.99, 482.14) and size (96.01, 170.90),median depth 12.0, features [0.08, 0.12, 0.32, -0.17, 0.70...], a chair with confidence 0.67 at center (937.75, 484.99) and size (137.21, 171.19),median depth 13.0, features [0.10, 0.21, 0.24, -0.20, 0.54...], a sports ball with confidence 0.53 at center (186.86, 503.49) and size (203.94, 153.40),median depth 7.0, features [0.29, 0.07, -0.27, 0.29, 0.21...], a refrigerator with confidence 0.53 at center (1700.18, 414.35) and size (434.70, 376.28),median depth 2.0, features [0.30, 0.12, 0.11, 0.35, 0.33...]. Robot is at translation (3.71, -0.48, 0.01) and orientation (0.00, 0.00, -0.09, 1.00).
# 20250416_120424_006.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120424_006.jpg, a chair with confidence 0.87 at center (1108.35, 453.45) and size (128.16, 252.10),median depth 9.0, features [0.09, 0.12, 0.17, 0.08, 0.51...], a chair with confidence 0.79 at center (731.61, 454.62) and size (192.75, 254.68),median depth 10.0, features [0.22, 0.16, 0.30, 0.03, 0.43...], a refrigerator with confidence 0.77 at center (1820.20, 499.95) and size (198.14, 255.14),median depth 2.0, features [0.09, -0.13, 0.10, 0.35, 0.01...], a dining table with confidence 0.54 at center (905.75, 461.19) and size (232.66, 239.33),median depth 9.0, features [0.24, 0.09, 0.23, 0.04, 0.15...]. Robot is at translation (6.21, -0.23, 0.01) and orientation (0.00, 0.00, -0.02, 1.00).
# ...
# 20250416_115205_965.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115205_965.jpg, a chair with confidence 0.81 at center (524.85, 493.83) and size (97.43, 145.94),median depth 14.0, features [0.13, 0.23, 0.11, -0.39, 0.76...]. Robot is at translation (2.14, 0.78, 0.01) and orientation (0.00, 0.00, -0.19, 0.98).
# 20250416_120523_974.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120523_974.jpg, a chair with confidence 0.62 at center (1881.47, 431.79) and size (76.20, 316.29),median depth 8.0, features [0.00, -0.05, 0.04, 0.10, 0.33...]. Robot is at translation (6.82, -0.02, 0.01) and orientation (0.00, 0.00, 0.28, 0.96).
# 20250416_120259_523.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120259_523.jpg, a bench with confidence 0.57 at center (278.16, 472.49) and size (510.57, 232.53),median depth 6.0, features [0.33, 0.42, 0.14, 0.11, 0.17...]. Robot is at translation (3.27, -0.56, 0.01) and orientation (0.00, 0.00, 0.36, 0.93).
# 20250416_115601_095.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115601_095.jpg, a chair with confidence 0.64 at center (1825.09, 436.93) and size (187.74, 280.34),median depth 6.0, features [-0.05, 0.16, -0.01, 0.26, 0.40...]. Robot is at translation (3.24, -1.71, 0.01) and orientation (0.00, 0.00, 0.95, 0.30).
# 20250416_120755_343.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120755_343.jpg, a vase with confidence 0.51 at center (1501.23, 502.27) and size (196.97, 245.07),median depth 2.0, features [-0.18, 0.32, 0.11, 0.10, 0.29...]. Robot is at translation (8.22, 1.02, 0.01) and orientation (0.00, 0.00, -0.64, 0.77).
# 20250416_115226_461.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115226_461.jpg, no objects detected. Robot is at translation (2.65, 0.53, 0.01) and orientation (0.00, 0.00, -0.33, 0.94).
# 20250416_120422_874.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120422_874.jpg, a chair with confidence 0.86 at center (990.85, 455.94) and size (126.72, 253.34),median depth 9.0, features [0.06, 0.20, 0.30, -0.18, 0.51...], a chair with confidence 0.76 at center (614.67, 453.35) and size (196.49, 254.12),median depth 9.0, features [0.26, 0.13, 0.36, 0.04, 0.41...], a vase with confidence 0.62 at center (1672.34, 500.67) and size (210.48, 244.27),median depth 2.0, features [0.12, -0.07, -0.10, 0.19, 0.28...], a dining table with confidence 0.55 at center (789.24, 461.19) and size (233.45, 239.45),median depth 9.0, features [0.13, 0.16, 0.23, 0.03, -0.03...]. Robot is at translation (6.17, -0.23, 0.01) and orientation (0.00, 0.00, -0.05, 1.00).
# 20250416_120300_653.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120300_653.jpg, a chair with confidence 0.53 at center (1795.81, 479.22) and size (166.68, 183.54),median depth 11.0, features [0.17, 0.16, 0.10, -0.08, 0.24...]. Robot is at translation (3.28, -0.55, 0.01) and orientation (0.00, 0.00, 0.34, 0.94).
# 20250416_115609_642.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115609_642.jpg, a bed with confidence 0.54 at center (523.31, 399.97) and size (981.99, 416.04),median depth 6.0, features [-0.08, -0.08, -0.25, 0.03, 0.04...]. Robot is at translation (3.22, -1.69, 0.01) and orientation (0.00, 0.00, 0.68, 0.73).
# 20250416_120023_325.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120023_325.jpg, a bench with confidence 0.51 at center (236.71, 505.40) and size (470.96, 168.82),median depth 5.0, features [0.02, 0.00, -0.03, 0.11, 0.20...]. Robot is at translation (2.87, -0.39, 0.01) and orientation (0.00, 0.00, -0.51, 0.86).
# 20250416_115803_636.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115803_636.jpg, a person with confidence 0.68 at center (1016.35, 288.59) and size (95.91, 134.90),median depth 8.0, features [-0.16, -0.10, -0.30, 0.15, 0.31...], a sports ball with confidence 0.50 at center (797.17, 484.53) and size (197.12, 190.02),median depth 5.0, features [0.09, 0.31, -0.21, 0.39, 0.34...]. Robot is at translation (3.90, -1.09, 0.01) and orientation (0.00, 0.00, 0.96, -0.29).
# 20250416_120940_684.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120940_684.jpg, a person with confidence 0.77 at center (429.09, 505.67) and size (105.46, 136.04),median depth 5.0, features [-0.37, -0.03, -0.26, 0.07, 0.07...], a refrigerator with confidence 0.62 at center (1810.10, 455.45) and size (217.44, 507.92),median depth 1.0, features [0.19, 0.17, 0.21, 0.34, 0.48...]. Robot is at translation (9.36, -1.51, 0.01) and orientation (0.00, 0.00, -0.72, 0.70).
# 20250416_120810_289.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120810_289.jpg, a chair with confidence 0.56 at center (431.52, 463.31) and size (230.65, 256.58),median depth 5.0, features [-0.04, 0.24, 0.02, -0.09, 0.57...]. Robot is at translation (8.47, 0.47, 0.01) and orientation (0.00, 0.00, -0.53, 0.85).
# 20250416_120525_749.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120525_749.jpg, a chair with confidence 0.71 at center (1697.26, 436.61) and size (160.75, 298.32),median depth 8.0, features [0.23, 0.10, 0.09, -0.11, 0.47...], a sports ball with confidence 0.62 at center (419.04, 482.11) and size (255.15, 264.94),median depth 4.0, features [0.56, 0.12, -0.40, 0.10, 0.40...]. Robot is at translation (6.85, -0.00, 0.01) and orientation (0.00, 0.00, 0.22, 0.97).
# 20250416_120949_005.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120949_005.jpg, no objects detected. Robot is at translation (9.33, -1.94, 0.01) and orientation (0.00, 0.00, -0.78, 0.62).
# 20250416_115927_224.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115927_224.jpg, no objects detected. Robot is at translation (3.65, 0.23, 0.01) and orientation (0.00, 0.00, 0.97, -0.26).
# 20250416_120238_903.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120238_903.jpg, no objects detected. Robot is at translation (3.25, -0.68, 0.01) and orientation (0.00, 0.00, 1.00, 0.07).
# 20250416_120348_151.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120348_151.jpg, a chair with confidence 0.92 at center (1780.82, 462.49) and size (128.62, 226.38),median depth 10.0, features [0.13, 0.03, 0.05, 0.11, 0.40...], a chair with confidence 0.84 at center (1424.57, 468.82) and size (161.54, 208.69),median depth 11.0, features [0.28, 0.09, 0.10, -0.24, 0.22...], a sports ball with confidence 0.72 at center (544.56, 498.90) and size (211.91, 180.52),median depth 6.0, features [0.36, 0.16, -0.04, 0.28, 0.24...], a dining table with confidence 0.51 at center (1586.17, 473.85) and size (204.41, 196.47),median depth 10.0, features [0.18, 0.12, 0.28, -0.19, 0.08...]. Robot is at translation (4.83, 0.04, 0.01) and orientation (0.00, 0.00, 0.09, 1.00).
# 20250416_120307_584.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120307_584.jpg, a bench with confidence 0.57 at center (1842.92, 479.80) and size (151.22, 181.18),median depth 11.0, features [0.14, 0.14, 0.01, -0.19, 0.41...]. Robot is at translation (3.35, -0.50, 0.01) and orientation (0.00, 0.00, 0.28, 0.96).
# 20250416_120052_965.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120052_965.jpg, a chair with confidence 0.84 at center (1193.41, 487.07) and size (130.06, 165.88),median depth 13.0, features [0.17, 0.14, -0.18, 0.08, 0.40...], a chair with confidence 0.72 at center (1460.53, 485.97) and size (95.33, 166.14),median depth 12.0, features [0.06, 0.22, 0.40, 0.18, 0.32...], a cup with confidence 0.57 at center (1730.55, 526.72) and size (110.31, 124.24),median depth 10.0, features [0.23, -0.14, -0.16, -0.17, 0.61...]. Robot is at translation (3.33, -0.26, 0.01) and orientation (0.00, 0.00, 0.07, 1.00).
# 20250416_115613_916.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115613_916.jpg, a airplane with confidence 0.60 at center (1191.88, 303.33) and size (1456.23, 586.81),median depth 8.0, features [0.26, 0.21, -0.16, 0.05, 0.13...]. Robot is at translation (3.22, -1.69, 0.01) and orientation (0.00, 0.00, 0.26, 0.97).
# 20250416_120324_086.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120324_086.jpg, a chair with confidence 0.82 at center (1776.57, 468.43) and size (115.69, 208.95),median depth 10.0, features [0.24, 0.11, 0.27, -0.19, 0.65...], a chair with confidence 0.75 at center (1459.31, 479.12) and size (156.78, 183.26),median depth 11.0, features [0.19, 0.16, 0.12, -0.07, 0.23...], a dining table with confidence 0.51 at center (1602.32, 479.19) and size (199.44, 183.12),median depth 11.0, features [-0.00, 0.23, 0.31, -0.07, -0.03...]. Robot is at translation (3.94, -0.25, 0.01) and orientation (0.00, 0.00, 0.16, 0.99).
# 20250416_120057_551.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120057_551.jpg, no objects detected. Robot is at translation (3.33, -0.26, 0.01) and orientation (0.00, 0.00, -0.32, 0.95).
# 20250416_120138_453.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120138_453.jpg, a chair with confidence 0.75 at center (1551.28, 485.21) and size (145.79, 172.81),median depth 12.0, features [0.06, -0.11, -0.22, -0.05, 0.56...], a dining table with confidence 0.52 at center (1693.33, 484.75) and size (189.25, 169.79),median depth 11.0, features [0.16, -0.05, -0.26, -0.20, 0.66...]. Robot is at translation (3.37, -0.30, 0.01) and orientation (0.00, 0.00, 0.48, 0.88).
# 20250416_120732_543.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120732_543.jpg, a bench with confidence 0.52 at center (608.74, 421.61) and size (325.83, 368.94),median depth 4.0, features [0.11, 0.34, 0.09, 0.05, 0.14...]. Robot is at translation (8.26, 1.14, 0.01) and orientation (0.00, 0.00, 0.85, 0.53).
# 20250416_120335_844.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120335_844.jpg, a chair with confidence 0.83 at center (1484.99, 472.72) and size (160.30, 200.27),median depth 11.0, features [0.16, 0.13, 0.27, -0.21, 0.34...], a chair with confidence 0.73 at center (1830.80, 464.91) and size (123.59, 221.83),median depth 10.0, features [0.25, 0.18, 0.25, -0.10, 0.59...], a chair with confidence 0.52 at center (1825.38, 495.96) and size (114.66, 158.40),median depth 10.0, features [0.13, 0.33, 0.19, 0.17, 0.50...], a dining table with confidence 0.52 at center (1641.90, 477.20) and size (208.12, 192.47),median depth 10.0, features [0.12, 0.14, 0.38, 0.23, 0.05...]. Robot is at translation (4.45, -0.09, 0.01) and orientation (0.00, 0.00, 0.16, 0.99).
# 20250416_120823_430.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120823_430.jpg, no objects detected. Robot is at translation (8.53, 0.25, 0.01) and orientation (0.00, 0.00, -0.68, 0.73).
# 20250416_120756_891.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120756_891.jpg, a vase with confidence 0.62 at center (1702.36, 499.46) and size (221.27, 261.93),median depth 2.0, features [0.03, 0.07, 0.17, 0.15, 0.40...], a chair with confidence 0.56 at center (52.01, 459.65) and size (103.76, 261.95),median depth 5.0, features [0.08, 0.32, 0.47, 0.39, 0.33...]. Robot is at translation (8.24, 0.95, 0.01) and orientation (0.00, 0.00, -0.61, 0.79).
# 20250416_115245_081.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115245_081.jpg, no objects detected. Robot is at translation (3.05, 0.00, 0.01) and orientation (0.00, 0.00, -0.52, 0.85).
# 20250416_121026_441.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_121026_441.jpg, a person with confidence 0.62 at center (789.76, 325.78) and size (141.44, 260.82),median depth 4.0, features [0.20, -0.05, -0.32, 0.43, 0.62...]. Robot is at translation (9.71, -1.92, 0.01) and orientation (0.00, 0.00, 0.51, 0.86).
# 20250416_120531_517.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120531_517.jpg, a chair with confidence 0.86 at center (1536.10, 433.14) and size (168.15, 308.94),median depth 8.0, features [0.06, 0.20, 0.07, 0.06, 0.34...], a chair with confidence 0.83 at center (1076.50, 438.27) and size (200.72, 293.95),median depth 9.0, features [0.22, 0.09, 0.25, -0.21, 0.38...], a refrigerator with confidence 0.62 at center (1787.02, 334.36) and size (264.98, 454.25),median depth 7.0, features [0.25, 0.11, -0.11, 0.13, 0.42...], a dining table with confidence 0.56 at center (1283.41, 444.95) and size (249.70, 288.72),median depth 8.0, features [0.17, -0.15, 0.11, 0.12, 0.22...]. Robot is at translation (7.11, 0.06, 0.01) and orientation (0.00, 0.00, 0.04, 1.00).
# 20250416_120807_573.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120807_573.jpg, no objects detected. Robot is at translation (8.44, 0.53, 0.01) and orientation (0.00, 0.00, -0.49, 0.87).
# 20250416_120200_637.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120200_637.jpg, a cup with confidence 0.56 at center (180.25, 527.21) and size (96.68, 118.96),median depth 6.0, features [0.24, -0.08, 0.18, -0.25, 0.28...]. Robot is at translation (3.39, -0.12, 0.01) and orientation (0.00, 0.00, 0.97, 0.24).
# 20250416_115736_470.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_115736_470.jpg, a traffic light with confidence 0.54 at center (905.22, 282.59) and size (30.46, 92.61),median depth 10.0, features [0.20, 0.01, 0.07, -0.00, 0.14...]. Robot is at translation (3.46, -1.59, 0.01) and orientation (0.00, 0.00, 0.29, 0.96).
# 20250416_114721_423.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_114721_423.jpg, no objects detected. Robot is at translation (-1.61, 1.46, 0.01) and orientation (0.00, 0.00, 0.30, 0.95).
# 20250416_120048_646.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_120048_646.jpg, a chair with confidence 0.74 at center (1872.91, 488.93) and size (93.26, 164.11),median depth 11.0, features [0.04, 0.05, 0.27, -0.32, 0.54...]. Robot is at translation (3.33, -0.26, 0.01) and orientation (0.00, 0.00, 0.28, 0.96).
# 20250416_121024_999.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_121024_999.jpg, a person with confidence 0.73 at center (702.98, 330.30) and size (145.76, 260.87),median depth 4.0, features [0.19, 0.01, -0.42, 0.30, 0.53...], a chair with confidence 0.55 at center (1279.36, 370.34) and size (339.23, 499.80),median depth 5.0, features [0.18, 0.02, 0.15, 0.36, 0.28...]. Robot is at translation (9.67, -1.99, 0.01) and orientation (0.00, 0.00, 0.49, 0.87).
# 20250416_121044_890.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_121044_890.jpg, a chair with confidence 0.81 at center (1794.94, 336.15) and size (246.91, 611.07),median depth 3.0, features [0.10, 0.12, 0.21, 0.03, 0.50...]. Robot is at translation (10.06, -1.47, 0.01) and orientation (0.00, 0.00, 0.32, 0.95).
# 20250416_114817_174.json: In the image at /ros2_ws/data_collection/20250416_114303/images/20250416_114817_174.jpg, a cup with confidence 0.55 at center (803.88, 398.68) and size (555.07, 784.57),median depth 1.0, features [0.00, 0.17, 0.00, 0.45, 0.31...]. Robot is at translation (-0.75, 2.45, 0.01) and orientation (0.00, 0.00, 0.93, 0.36).

# %%
def save_prompts_to_json(prompts, output_file):
    """
    Saves the generated prompts to a JSON file.

    Args:
        prompts (dict): A dictionary where keys are filenames and values are generated prompts.
        output_file (str): Path to the output JSON file.
    """
    with open(output_file, 'w') as file:
        json.dump(prompts, file, indent=4)

# %%
output_file = "/Users/esort/Documents/s24/DL/generated_prompts.json"
save_prompts_to_json(vlm_prompts, output_file)
